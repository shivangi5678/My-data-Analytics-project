# %% [markdown]
# <a href="https://colab.research.google.com/github/shivangi5678/My-data-Analytics-project/blob/main/netflix1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-67d3f764-0d8e-4031-9354-f7fee33534f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67d3f764-0d8e-4031-9354-f7fee33534f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install opendatasets
import opendatasets as od
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv("/content/netflix_titles.csv")
print(df.head())
print ("shape:", df.shape)
print(df.info())
print(df. describe())
print(df.isnull().sum())
print(df.duplicated().sum())
df.drop_duplicates(inplace=True)
#missing value fill karna
df['director'].fillna('Unknown',inplace=True)
df['cast'].fillna('Unknown',inplace=True)
df['country'].fillna('Unknown',inplace=True)
#date ko drop kar sakte hai
df.dropna(subset=['date_added'], inplace=True)
df['date_added'] = pd.to_datetime(df['date_added'], format='mixed', errors='coerce')
df['year_addes'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
df.duplicated().sum()
df.isnull().sum()
df['rating'].fillna('Not rated' , inplace=True)
df['duration'].fillna('Unknown', inplace=True)
df.isnull().sum()
#basic analysis
df['type'].value_counts()
df['rating'].value_counts()
df['country'].value_counts().head(10)
df['release_year'].value_counts().sort_index()
df['month_added'].value_counts()
#data visualization
plt.figure(figsize=(10,6))
sns.countplot(x='type' , data=df)
plt.show()
df.to_csv('netflix_titles.csv', index=False)
# Out:
# ...
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25          2020  PG-13     90 min
# 1  2021-09-24          2021  TV-MA  2 Seasons
# 2  2021-09-24          2021  TV-MA   1 Season
# ...
